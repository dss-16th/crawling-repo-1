# %%
from time import sleep
import datetime 
from datetime import datetime

# %%
def input_date():
    date = input("날짜를 입력하세요(예시:20200202) : ")
    #datetimeobject = datetime.strptime(day,'%Y%m%d')
    #newformat = datetimeobject.strftime('%Y-%m-%d')
    #new = newformat.split("-")
    y = int(date[0:4])
    m = int(date[4:6])
    d = int(date[6:8])


    return y, m, d


def is_leap(num):

    if (num % 4) ==0:

        if (num % 400) == 0: 

            return True

        elif (num % 100) == 0: 

            return False

        else: 

            return True
    else: 

        return False

# %%
def get_day_name(year, month, day):
    from datetime import datetime
    dt = datetime(year, month, day)

    dt = int(dt.strftime("%j"))

    count_day = 0

    for i in range(year):

        if is_leap(i): 

            count_day += 366

        else: 

            count_day += 365

    count = (count_day + dt - 366) %  7 

    #1년 1월 1일은 0일째이지만 컴퓨터에서는 366일째로 계산되기 때문에 366을 빼줌.

    return {0: '일요일', 1: "월요일", 2: "화요일", 3: "수요일",

            4: "목요일", 5: "금요일", 6: "토요일"}[count]

def date_datetime(year, month, day,day_name):
    import datetime
    date = datetime.date(year, month, day)
    if day_name == "월요일":
         date = date-datetime.timedelta(3)
    elif day_name == "화요일":
        date = date-datetime.timedelta(4)
    elif day_name == "수요일":
        date = date-datetime.timedelta(5)
    elif day_name == "목요일":
        date = date-datetime.timedelta(6)
    elif day_name == "금요일":
        date = date#date-datetime.timedelta(4)
    elif day_name == "토요일":
        date = date-datetime.timedelta(1)
    else:
        date= date-datetime.timedelta(2)
    start_date = date.strftime("%y%m%d")
    start_date = int(start_date)
    end_date = date + datetime.timedelta(days=6)
    end_date = end_date.strftime("%y%m%d")
    end_date = int(end_date)
    return start_date, end_date

# 금(start_date=date) 토(date+1) 일(date+2) 월(date+3) 화(date+4) 수(date+5) 목(end_date)
if __name__ == "__main__":

    year, month, day = input_date()

    day_name = get_day_name(year, month, day)
    
    date_datetime = date_datetime(year, month, day,day_name)
    
start_date,end_date = date_datetime
day_name,start_date,end_date
#02  -0225
#0226-0304
# Out:
# 날짜를 입력하세요(예시:20200202) : 20210226
# ('금요일', 210226, 210304)

# %%
import requests
# \w+\W+\w+
import re
url = "https://charts.youtube.com/charts/TopSongs/kr?hl=ko"
response = requests.get(url)
key = re.findall('"INNERTUBE_API_KEY":"\w+\W+\w+"', response.text)[0].split(":")[1].replace('"','')
key
# Out:
# 'AIzaSyCzEW7JUJdSql0-2V4tHUb6laYm4iAE_dM'

# %%
url = f'https://charts.youtube.com/youtubei/v1/browse?\
alt=json&key={key}'
response = requests.post(url)
datas = response.json()
datas
# Out:
# {'error': {'code': 403,
#   'message': 'Requests from referer <empty> are blocked.',
#   'errors': [{'message': 'Requests from referer <empty> are blocked.',
#     'domain': 'global',
#     'reason': 'forbidden'}],
#   'status': 'PERMISSION_DENIED'}}

# %%
url = f'https://charts.youtube.com/youtubei/v1/browse?\
alt=json&key={key}'
headers = {"referer": "https://charts.youtube.com/charts/TopSongs/kr?hl=ko"}
response = requests.post(url, headers=headers)
datas = response.json()
datas
# Out:
# {'error': {'code': 400,
#   'message': 'Precondition check failed.',
#   'errors': [{'message': 'Precondition check failed.',
#     'domain': 'global',
#     'reason': 'failedPrecondition'}],
#   'status': 'FAILED_PRECONDITION'}}

# %%
url = f'https://charts.youtube.com/youtubei/v1/browse?\
alt=json&key={key}'
query = {"context":{"client":
                    {"clientName":"WEB_MUSIC_ANALYTICS","clientVersion":"0.2","hl":"ko","gl":"KR",
                     "experimentIds":[],"experimentsToken":"","theme":"MUSIC"},"capabilities":{},
                    "request":{"internalExperimentFlags":[]}},"browseId":"FEmusic_analytics_charts_home",
         "query":f"chart_params_type=WEEK&perspective=CHART&flags=viral_video_chart&selected_chart=TRACKS\
         &chart_params_id=weekly:{int(start_date)}:{int(end_date)}:kr"}
headers = {"referer": "https://charts.youtube.com/charts/TopSongs/kr?hl=ko"}
response = requests.post(url, json=query, headers=headers)
datas = response.json()
datas
# Out:
# {'responseContext': {'visitorData': 'CgsxbnNENXBlc2hBZyjkz5OCBg%3D%3D'},
#  'trackingParams': 'CAAQhGciEwj-orHbtp7vAhXNFa0GHXu6BDk=',
#  'contents': {'sectionListRenderer': {'contents': [{'musicAnalyticsSectionRenderer': {'content': {'perspectiveMetadata': {'entityId': 'weekly:210219:210225:kr',
#         'chartRestrictions': {'chartPeriods': [{'id': 'weekly:20210226:20210304:kr',
#            'startTime': '2021-02-26',
#            'endTime': '2021-03-04'},
#           {'id': 'weekly:20210219:20210225:kr',
#            'startTime': '2021-02-19',
#            'endTime': '2021-02-25'},
#           {'id': 'weekly:20210212:20210218:kr',
#            'startTime': '2021-02-12',
#            'endTime': '2021-02-18'},
#           {'id': 'weekly:20210205:20210211:kr',
#            'startTime': '2021-02-05',
#            'endTime': '2021-02-11'},
#           {'id': 'weekly:20210129:20210204:kr',
#            'startTime': '2021-01-29',
#            'endTime': '2021-02-04'},
# ...

# %%
url = f'https://charts.youtube.com/youtubei/v1/browse?\
alt=json&key={key}'
query = {"context":{"client":
                    {"clientName":"WEB_MUSIC_ANALYTICS","clientVersion":"0.2","hl":"ko","gl":"KR",
                     "experimentIds":[],"experimentsToken":"","theme":"MUSIC"},"capabilities":{},
                    "request":{"internalExperimentFlags":[]}},"browseId":"FEmusic_analytics_charts_home",
         "query":f"chart_params_type=WEEK&perspective=CHART&flags=viral_video_chart&selected_chart=TRACKS\
         &chart_params_id=weekly:{start_date}:end_date:kr"}
headers = {"referer": "https://charts.youtube.com/charts/TopSongs/kr?hl=ko"}
response = requests.post(url, json=query, headers=headers)
datas = response.json()["contents"]["sectionListRenderer"]["contents"][0]["musicAnalyticsSectionRenderer"]["content"]["trackTypes"][0]["trackViews"]
datas
# Out:
# [{'id': 'G:ok5zPuiwzmQ',
#   'name': 'Celebrity',
#   'viewCount': '2338502',
#   'thumbnail': {'thumbnails': [{'url': 'https://i.ytimg.com/vi/0-q1KafFCLU/default.jpg',
#      'width': 120,
#      'height': 90},
#     {'url': 'https://i.ytimg.com/vi/0-q1KafFCLU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     {'url': 'https://i.ytimg.com/vi/0-q1KafFCLU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     {'url': 'https://i.ytimg.com/vi/0-q1KafFCLU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     {'url': 'https://i.ytimg.com/vi/0-q1KafFCLU/maxresdefault.jpg',
#      'width': 1920,
#      'height': 1080}]},
#   'encryptedVideoId': '0-q1KafFCLU',
#   'chartEntryMetadata': {'currentPosition': 1,
#    'previousPosition': 1,
#    'percentViewsChange': -0.18518186,
#    'periodsOnChart': 6},
#   'artists': [{'kgMid': '/m/0fr0bhg', 'name': '아이유(IU)'}],
#   'isVisible': True},
#  {'id': 'G:PbqZdrF8L2g',
#   'name': 'Dynamite',
# ...

# %%
title = [{"title":data["name"]}
        for data in datas]
title
# Out:
# [{'title': 'Celebrity'},
#  {'title': 'Dynamite'},
#  {'title': '팅커벨 (Tinker Bell)'},
#  {'title': '꼬리 (TAIL)'},
#  {'title': "롤린(Rollin')"},
#  {'title': "Don't Call Me"},
#  {'title': 'Lovesick Girls'},
#  {'title': '블루밍 (Blueming)'},
#  {'title': 'Panorama'},
#  {'title': 'FRIENDS (원슈타인 & Lil Boi)'},
#  {'title': 'I’m Not Cool'},
#  {'title': 'WANNABE'},
#  {'title': '화 (火花) [HWAA]'},
#  {'title': 'Life Goes On'},
#  {'title': "I CAN'T STOP ME"},
#  {'title': 'Black Mamba'},
#  {'title': 'How You Like That'},
#  {'title': 'Bicycle'},
#  {'title': '살짝 설렜어 (Nonstop)'},
#  {'title': 'Actually.. I miss you (사실 나는) (feat. 전건호)'},
#  {'title': '밤하늘의 별을 (Shiny Star)'},
#  {'title': 'Ashes'},
#  {'title': '잠이 오질 않네요'},
#  {'title': '에잇 (feat. SUGA of BTS)'},
#  {'title': 'MELODY'},
#  {'title': '취기를 빌려 (Slightly Tipsy)'},
#  {'title': "WHY DON'T WE (Live) (feat. 청하)"},
#  {'title': '옜다 (Take It) (머쉬베놈 & 저스디스)'},
#  {'title': '테스형!'},
#  {'title': '붓'},
#  {'title': 'Fix You'},
# ...

# %%
artist = [{"artist":data["artists"][0]["name"]}
        for data in datas]
artist
# Out:
# [{'artist': '아이유(IU)'},
#  {'artist': 'BTS(방탄소년단)'},
#  {'artist': '에이프릴(APRIL)'},
#  {'artist': '선미 '},
#  {'artist': '브레이브걸스'},
#  {'artist': '샤이니'},
#  {'artist': 'BLACKPINK'},
#  {'artist': '아이유(IU)'},
#  {'artist': 'IZ*ONE (아이즈원)'},
#  {'artist': '원슈타인'},
#  {'artist': '현아(HyunA)'},
#  {'artist': 'ITZY'},
#  {'artist': '(여자)아이들'},
#  {'artist': 'BTS(방탄소년단)'},
#  {'artist': 'TWICE(트와이스)'},
#  {'artist': '에스파'},
#  {'artist': 'BLACKPINK'},
#  {'artist': '청하'},
#  {'artist': '오마이걸(OH MY GIRL)'},
#  {'artist': '경서예지'},
#  {'artist': 'KyoungSeo'},
#  {'artist': '스텔라'},
#  {'artist': '장범준'},
#  {'artist': '아이유(IU)'},
#  {'artist': 'ASH ISLAND'},
#  {'artist': '산들'},
#  {'artist': '비(RAIN)'},
#  {'artist': '머쉬베놈'},
#  {'artist': '나훈아'},
#  {'artist': '강진'},
#  {'artist': 'Coldplay(콜드플레이)'},
#  {'artist': '빅나티'},
#  {'artist': 'BLACKPINK'},
#  {'artist': '10cm(십센치)'},
#  {'artist': 'Ariana Grande(아리아나 그란데)'},
#  {'artist': '에이제이알'},
#  {'artist': '강다니엘'},
#  {'artist': 'BLACKPINK'},
# ...

# %%
viewCount = [{"viewCount":str(round((float(data["viewCount"])/1000000),2)) + "M"}
        for data in datas]
viewCount
# Out:
# [{'viewCount': '2.34M'},
#  {'viewCount': '2.09M'},
#  {'viewCount': '1.92M'},
#  {'viewCount': '1.51M'},
#  {'viewCount': '1.41M'},
#  {'viewCount': '1.17M'},
#  {'viewCount': '1.14M'},
#  {'viewCount': '0.95M'},
#  {'viewCount': '0.91M'},
#  {'viewCount': '0.8M'},
#  {'viewCount': '0.75M'},
#  {'viewCount': '0.72M'},
#  {'viewCount': '0.72M'},
#  {'viewCount': '0.68M'},
#  {'viewCount': '0.65M'},
#  {'viewCount': '0.63M'},
#  {'viewCount': '0.62M'},
#  {'viewCount': '0.62M'},
#  {'viewCount': '0.58M'},
#  {'viewCount': '0.57M'},
#  {'viewCount': '0.56M'},
#  {'viewCount': '0.55M'},
#  {'viewCount': '0.53M'},
#  {'viewCount': '0.51M'},
#  {'viewCount': '0.5M'},
#  {'viewCount': '0.48M'},
#  {'viewCount': '0.48M'},
#  {'viewCount': '0.46M'},
#  {'viewCount': '0.46M'},
#  {'viewCount': '0.46M'},
#  {'viewCount': '0.45M'},
#  {'viewCount': '0.45M'},
#  {'viewCount': '0.43M'},
#  {'viewCount': '0.43M'},
#  {'viewCount': '0.42M'},
#  {'viewCount': '0.41M'},
#  {'viewCount': '0.41M'},
# ...

# %%
play_url = [{"play_url":"https://www.youtube.com/watch?v=" + data["encryptedVideoId"]}
        for data in datas]
play_url
# Out:
# [{'play_url': 'https://www.youtube.com/watch?v=0-q1KafFCLU'},
#  {'play_url': 'https://www.youtube.com/watch?v=gdZLi9oWNZg'},
#  {'play_url': 'https://www.youtube.com/watch?v=B9FTAcOK3cA'},
#  {'play_url': 'https://www.youtube.com/watch?v=Aui0ZKIaXVc'},
#  {'play_url': 'https://www.youtube.com/watch?v=MthLgPs7oU4'},
#  {'play_url': 'https://www.youtube.com/watch?v=p6OoY6xneI0'},
#  {'play_url': 'https://www.youtube.com/watch?v=dyRsYk0LyA8'},
#  {'play_url': 'https://www.youtube.com/watch?v=D1PvIWdJ8xo'},
#  {'play_url': 'https://www.youtube.com/watch?v=G8GaQdW2wHc'},
#  {'play_url': 'https://www.youtube.com/watch?v=aGrRfAs1fz8'},
#  {'play_url': 'https://www.youtube.com/watch?v=_yXEnhyOTQo'},
#  {'play_url': 'https://www.youtube.com/watch?v=fE2h3lGlOsk'},
#  {'play_url': 'https://www.youtube.com/watch?v=z3szNvgQxHo'},
#  {'play_url': 'https://www.youtube.com/watch?v=-5q5mZbe3V8'},
#  {'play_url': 'https://www.youtube.com/watch?v=CM4CkVFmTds'},
# ...

# %%
image = [{"image":data["thumbnail"]["thumbnails"][1]["url"]}
        for data in datas]
image
# Out:
# [{'image': 'https://i.ytimg.com/vi/0-q1KafFCLU/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/gdZLi9oWNZg/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/B9FTAcOK3cA/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/Aui0ZKIaXVc/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/MthLgPs7oU4/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/p6OoY6xneI0/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/dyRsYk0LyA8/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/D1PvIWdJ8xo/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/G8GaQdW2wHc/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/aGrRfAs1fz8/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/_yXEnhyOTQo/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/fE2h3lGlOsk/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/z3szNvgQxHo/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/-5q5mZbe3V8/mqdefault.jpg'},
#  {'image': 'https://i.ytimg.com/vi/CM4CkVFmTds/mqdefault.jpg'},
# ...

# %%
chartEntryMetadata= [{"change":data["chartEntryMetadata"]}
        for data in datas]
chartEntryMetadata
# Out:
# [{'change': {'currentPosition': 1,
#    'previousPosition': 1,
#    'percentViewsChange': -0.18518186,
#    'periodsOnChart': 6}},
#  {'change': {'currentPosition': 2,
#    'previousPosition': 5,
#    'percentViewsChange': 0.43777213,
#    'periodsOnChart': 28}},
#  {'change': {'currentPosition': 3, 'periodsOnChart': 1}},
#  {'change': {'currentPosition': 4,
#    'previousPosition': 3,
#    'percentViewsChange': -0.16270202,
#    'periodsOnChart': 2}},
#  {'change': {'currentPosition': 5,
#    'previousPosition': 11,
#    'percentViewsChange': 0.4041695,
#    'periodsOnChart': 6}},
#  {'change': {'currentPosition': 6,
#    'previousPosition': 4,
#    'percentViewsChange': -0.23083471,
#    'periodsOnChart': 2}},
#  {'change': {'currentPosition': 7,
#    'previousPosition': 6,
#    'percentViewsChange': -0.16182752,
#    'periodsOnChart': 22}},
#  {'change': {'currentPosition': 8,
#    'percentViewsChange': 2.0903249,
#    'periodsOnChart': 53}},
#  {'change': {'currentPosition': 9,
# ...

# %%
current_Rank= [{"current_Rank":data['chartEntryMetadata'].get('currentPosition')}
        for data in datas]
current_Rank
# Out:
# [{'current_Rank': 1},
#  {'current_Rank': 2},
#  {'current_Rank': 3},
#  {'current_Rank': 4},
#  {'current_Rank': 5},
#  {'current_Rank': 6},
#  {'current_Rank': 7},
#  {'current_Rank': 8},
#  {'current_Rank': 9},
#  {'current_Rank': 10},
#  {'current_Rank': 11},
#  {'current_Rank': 12},
#  {'current_Rank': 13},
#  {'current_Rank': 14},
#  {'current_Rank': 15},
#  {'current_Rank': 16},
#  {'current_Rank': 17},
#  {'current_Rank': 18},
#  {'current_Rank': 19},
#  {'current_Rank': 20},
#  {'current_Rank': 21},
#  {'current_Rank': 22},
#  {'current_Rank': 23},
#  {'current_Rank': 24},
#  {'current_Rank': 25},
#  {'current_Rank': 26},
#  {'current_Rank': 27},
#  {'current_Rank': 28},
#  {'current_Rank': 29},
#  {'current_Rank': 30},
#  {'current_Rank': 31},
#  {'current_Rank': 32},
#  {'current_Rank': 33},
#  {'current_Rank': 34},
#  {'current_Rank': 35},
#  {'current_Rank': 36},
#  {'current_Rank': 37},
#  {'current_Rank': 38},
#  {'current_Rank': 39},
#  {'current_Rank': 40},
# ...

# %%
previous_Rank= [{"previous_Rank":data['chartEntryMetadata'].get('previousPosition')}
        for data in datas]
previous_Rank
# Out:
# [{'previous_Rank': 1},
#  {'previous_Rank': 5},
#  {'previous_Rank': None},
#  {'previous_Rank': 3},
#  {'previous_Rank': 11},
#  {'previous_Rank': 4},
#  {'previous_Rank': 6},
#  {'previous_Rank': None},
#  {'previous_Rank': 8},
#  {'previous_Rank': None},
#  {'previous_Rank': 9},
#  {'previous_Rank': 13},
#  {'previous_Rank': 10},
#  {'previous_Rank': 2},
#  {'previous_Rank': 14},
#  {'previous_Rank': 15},
#  {'previous_Rank': 17},
#  {'previous_Rank': 16},
#  {'previous_Rank': 19},
#  {'previous_Rank': 21},
#  {'previous_Rank': 20},
#  {'previous_Rank': 18},
#  {'previous_Rank': 23},
#  {'previous_Rank': 22},
#  {'previous_Rank': None},
#  {'previous_Rank': 25},
#  {'previous_Rank': None},
#  {'previous_Rank': 7},
#  {'previous_Rank': 27},
#  {'previous_Rank': None},
#  {'previous_Rank': None},
#  {'previous_Rank': None},
#  {'previous_Rank': None},
#  {'previous_Rank': 26},
#  {'previous_Rank': 30},
#  {'previous_Rank': 33},
#  {'previous_Rank': 12},
#  {'previous_Rank': 29},
# ...

# %%
change= [{"change":data['chartEntryMetadata'].get('percentViewsChange')}
        for data in datas]
change
# Out:
# [{'change': -0.18518186},
#  {'change': 0.43777213},
#  {'change': None},
#  {'change': -0.16270202},
#  {'change': 0.4041695},
#  {'change': -0.23083471},
#  {'change': -0.16182752},
#  {'change': 2.0903249},
#  {'change': -0.15470675},
#  {'change': None},
#  {'change': -0.28950086},
#  {'change': -0.07459786},
#  {'change': -0.3152512},
#  {'change': -0.6477039},
#  {'change': -0.16713017},
#  {'change': -0.15607335},
#  {'change': -0.11080696},
#  {'change': -0.12723812},
#  {'change': -0.07924889},
#  {'change': -0.06399206},
#  {'change': -0.09735437},
#  {'change': -0.15869927},
#  {'change': 0.008068401},
#  {'change': -0.14554931},
#  {'change': None},
#  {'change': -0.0459009},
#  {'change': None},
#  {'change': -0.60190463},
#  {'change': -0.039510157},
#  {'change': None},
#  {'change': None},
#  {'change': None},
#  {'change': 0.5292989},
#  {'change': -0.13749574},
#  {'change': -0.07469755},
#  {'change': -0.038819797},
#  {'change': -0.48222366},
# ...

# %%
chartEntryMetadata= [{"currentRank":data["chartEntryMetadata"]['currentPosition']}
        for data in datas]
chartEntryMetadata
# Out:
# [{'currentRank': 1},
#  {'currentRank': 2},
#  {'currentRank': 3},
#  {'currentRank': 4},
#  {'currentRank': 5},
#  {'currentRank': 6},
#  {'currentRank': 7},
#  {'currentRank': 8},
#  {'currentRank': 9},
#  {'currentRank': 10},
#  {'currentRank': 11},
#  {'currentRank': 12},
#  {'currentRank': 13},
#  {'currentRank': 14},
#  {'currentRank': 15},
#  {'currentRank': 16},
#  {'currentRank': 17},
#  {'currentRank': 18},
#  {'currentRank': 19},
#  {'currentRank': 20},
#  {'currentRank': 21},
#  {'currentRank': 22},
#  {'currentRank': 23},
#  {'currentRank': 24},
#  {'currentRank': 25},
#  {'currentRank': 26},
#  {'currentRank': 27},
#  {'currentRank': 28},
#  {'currentRank': 29},
#  {'currentRank': 30},
#  {'currentRank': 31},
#  {'currentRank': 32},
#  {'currentRank': 33},
#  {'currentRank': 34},
#  {'currentRank': 35},
#  {'currentRank': 36},
#  {'currentRank': 37},
#  {'currentRank': 38},
#  {'currentRank': 39},
#  {'currentRank': 40},
#  {'currentRank': 41},
#  {'currentRank': 42},
# ...

# %%
period_on_chart= [{"period_on_chart":str(data['chartEntryMetadata'].get('periodsOnChart')) + " week"}
        for data in datas]
period_on_chart
# Out:
# [{'period_on_chart': '6 week'},
#  {'period_on_chart': '28 week'},
#  {'period_on_chart': '1 week'},
#  {'period_on_chart': '2 week'},
#  {'period_on_chart': '6 week'},
#  {'period_on_chart': '2 week'},
#  {'period_on_chart': '22 week'},
#  {'period_on_chart': '53 week'},
#  {'period_on_chart': '13 week'},
#  {'period_on_chart': '1 week'},
#  {'period_on_chart': '6 week'},
#  {'period_on_chart': '52 week'},
#  {'period_on_chart': '8 week'},
#  {'period_on_chart': '15 week'},
#  {'period_on_chart': '19 week'},
#  {'period_on_chart': '16 week'},
#  {'period_on_chart': '36 week'},
#  {'period_on_chart': '3 week'},
#  {'period_on_chart': '45 week'},
#  {'period_on_chart': '20 week'},
#  {'period_on_chart': '16 week'},
#  {'period_on_chart': '6 week'},
#  {'period_on_chart': '19 week'},
#  {'period_on_chart': '44 week'},
#  {'period_on_chart': '1 week'},
#  {'period_on_chart': '32 week'},
#  {'period_on_chart': '1 week'},
#  {'period_on_chart': '7 week'},
# ...

# %%
data_1 = [
    {"title": data["name"], "artist":data["artists"][0]["name"],
    "viewCount":data["viewCount"] + "M",
     "current_Rank":data["chartEntryMetadata"].get('currentPosition'),
    "previous_Rank":data['chartEntryMetadata'].get('previousPosition'),
     "change":data['chartEntryMetadata'].get('percentViewsChange'),
     "period_on_chart":str(data['chartEntryMetadata'].get('periodsOnChart')) + " week",
     "image":data["thumbnail"]["thumbnails"][1]["url"],
    "play_url":"https://www.youtube.com/watch?v=" + data["encryptedVideoId"],
    } 
    for data in datas
]

data_1
# Out:
# [{'title': 'Celebrity',
#   'artist': '아이유(IU)',
#   'viewCount': '2338502M',
#   'current_Rank': 1,
#   'previous_Rank': 1,
#   'change': -0.18518186,
#   'period_on_chart': '6 week',
#   'image': 'https://i.ytimg.com/vi/0-q1KafFCLU/mqdefault.jpg',
#   'play_url': 'https://www.youtube.com/watch?v=0-q1KafFCLU'},
#  {'title': 'Dynamite',
#   'artist': 'BTS(방탄소년단)',
#   'viewCount': '2087336M',
#   'current_Rank': 2,
#   'previous_Rank': 5,
#   'change': 0.43777213,
#   'period_on_chart': '28 week',
#   'image': 'https://i.ytimg.com/vi/gdZLi9oWNZg/mqdefault.jpg',
#   'play_url': 'https://www.youtube.com/watch?v=gdZLi9oWNZg'},
#  {'title': '팅커벨 (Tinker Bell)',
#   'artist': '에이프릴(APRIL)',
#   'viewCount': '1916909M',
#   'current_Rank': 3,
#   'previous_Rank': None,
#   'change': None,
#   'period_on_chart': '1 week',
#   'image': 'https://i.ytimg.com/vi/B9FTAcOK3cA/mqdefault.jpg',
#   'play_url': 'https://www.youtube.com/watch?v=B9FTAcOK3cA'},
#  {'title': '꼬리 (TAIL)',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_1)
df.head()
# Out:
#                title       artist viewCount  current_Rank  previous_Rank  \
# 0          Celebrity      아이유(IU)  2338502M             1            1.0
# 1           Dynamite   BTS(방탄소년단)  2087336M             2            5.0
# 2  팅커벨 (Tinker Bell)  에이프릴(APRIL)  1916909M             3            NaN
# 3          꼬리 (TAIL)          선미   1511775M             4            3.0
# 4        롤린(Rollin')       브레이브걸스  1412148M             5           11.0
#
#      change period_on_chart                                             image  \
# 0 -0.185182          6 week  https://i.ytimg.com/vi/0-q1KafFCLU/mqdefault.jpg
# 1  0.437772         28 week  https://i.ytimg.com/vi/gdZLi9oWNZg/mqdefault.jpg
# 2       NaN          1 week  https://i.ytimg.com/vi/B9FTAcOK3cA/mqdefault.jpg
# 3 -0.162702          2 week  https://i.ytimg.com/vi/Aui0ZKIaXVc/mqdefault.jpg
# 4  0.404170          6 week  https://i.ytimg.com/vi/MthLgPs7oU4/mqdefault.jpg
#
#                                       play_url
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            100 non-null    object
#  1   artist           100 non-null    object
#  2   viewCount        100 non-null    object
#  3   current_Rank     100 non-null    int64
#  4   previous_Rank    74 non-null     float64
#  5   change           77 non-null     float64
#  6   period_on_chart  100 non-null    object
#  7   image            100 non-null    object
#  8   play_url         100 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 7.2+ KB

# %%
df['previous_Rank']
# Out:
# 0      1.0
# 1      5.0
# 2      NaN
# 3      3.0
# 4     11.0
#       ...
# 95    91.0
# 96    90.0
# 97     NaN
# 98    92.0
# 99     NaN
# Name: previous_Rank, Length: 100, dtype: float64

# %%
import numpy as np
df = df.replace(np.nan,0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            100 non-null    object
#  1   artist           100 non-null    object
#  2   viewCount        100 non-null    object
#  3   current_Rank     100 non-null    int64
#  4   previous_Rank    100 non-null    float64
#  5   change           100 non-null    float64
#  6   period_on_chart  100 non-null    object
#  7   image            100 non-null    object
#  8   play_url         100 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 7.2+ KB

# %%
df['previous_Rank'].astype(int)
# Out:
# 0      1
# 1      5
# 2      0
# 3      3
# 4     11
#       ..
# 95    91
# 96    90
# 97     0
# 98    92
# 99     0
# Name: previous_Rank, Length: 100, dtype: int64

# %%
df['previous_Rank'] = df['previous_Rank'].astype(int)
df
# Out:
#                                                 title        artist viewCount  \
# 0                                           Celebrity       아이유(IU)  2338502M
# 1                                            Dynamite    BTS(방탄소년단)  2087336M
# 2                                   팅커벨 (Tinker Bell)   에이프릴(APRIL)  1916909M
# 3                                           꼬리 (TAIL)           선미   1511775M
# 4                                         롤린(Rollin')        브레이브걸스  1412148M
# ..                                                ...           ...       ...
# 95                                 도망가자 (Run With Me)          선우정아   186736M
# 96                                          90's Love         NCT U   183830M
# 97  사임쌓임 (Racks On Racks) (Chin, SUPERBEE, Ck & 언에...          Chin   181158M
# 98                                                AYA  마마무(MAMAMOO)   178025M
# 99                     Can I Love ? (feat. 유라(youra))         코스믹보이   177404M
#
# ...

# %%
df['change'] = round(df['change'] * 100,1).astype(str) + "%"
df.head()
# Out:
#                title       artist viewCount  current_Rank  previous_Rank  \
# 0          Celebrity      아이유(IU)  2338502M             1              1
# 1           Dynamite   BTS(방탄소년단)  2087336M             2              5
# 2  팅커벨 (Tinker Bell)  에이프릴(APRIL)  1916909M             3              0
# 3          꼬리 (TAIL)          선미   1511775M             4              3
# 4        롤린(Rollin')       브레이브걸스  1412148M             5             11
#
#    change period_on_chart                                             image  \
# 0  -18.5%          6 week  https://i.ytimg.com/vi/0-q1KafFCLU/mqdefault.jpg
# 1   43.8%         28 week  https://i.ytimg.com/vi/gdZLi9oWNZg/mqdefault.jpg
# 2    0.0%          1 week  https://i.ytimg.com/vi/B9FTAcOK3cA/mqdefault.jpg
# 3  -16.3%          2 week  https://i.ytimg.com/vi/Aui0ZKIaXVc/mqdefault.jpg
# 4   40.4%          6 week  https://i.ytimg.com/vi/MthLgPs7oU4/mqdefault.jpg
#
#                                       play_url
# ...

# %%
import scrapy
import requests
from scrapy.http import TextResponse

# %%
# !scrapy startproject youtube_chart
# Out:
# Error: scrapy.cfg already exists in /home/ubuntu/youtube_chart

# %%
# %load youtube_chart/youtube_chart/items.py
# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy


class YoutubeChartItem(scrapy.Item):
    # define the fields for your item here like:
    # name = scrapy.Field()
    pass

# %%
# %%writefile youtube_chart/youtube_chart/items.py

import scrapy


class YoutubeChartItem(scrapy.Item):
    # define the fields for your item here like:
    name = scrapy.Field()
    viewCount = scrapy.Field()
    current_Rank = scrapy.Field()
    previous_Rank = scrapy.Field()
    change = scrapy.Field()
    period_on_chart = scrapy.Field()
    image = scrapy.Field()
    play_url = scrapy.Field()
# Out:
# Overwriting youtube_chart/youtube_chart/items.py

# %%
# %%writefile youtube_chart/youtube_chart/spiders/spirder.py

import scrapy
import requests
from youtube_chart.items import YoutubeChartItem

class chartspider(scrapy.Spider):
    name = "YoutubeChart"
    allow_domain = ["https://charts.youtube.com/charts/TopSongs/kr?hl=ko"]
    
    def __init__(self, key="AIzaSyCzEW7JUJdSql0-2V4tHUb6laYm4iAE_dM",strat_date="210301",end_date="210307",**kwargs):
        self.start_urls = [f"https://charts.youtube.com/youtubei/v1/browse?\
alt=json&key={key}"]
        self.query = {"context":{"client":
                    {"clientName":"WEB_MUSIC_ANALYTICS","clientVersion":"0.2","hl":"ko","gl":"KR",
                     "experimentIds":[],"experimentsToken":"","theme":"MUSIC"},"capabilities":{},
                    "request":{"internalExperimentFlags":[]}},"browseId":"FEmusic_analytics_charts_home",
         "query":f"chart_params_type=WEEK&perspective=CHART&flags=viral_video_chart&selected_chart=TRACKS\
         &chart_params_id=weekly:{strat_date}:{end_date}:kr"}
        super().__init__(**kwargs)
                  
    def start_requests(self):
        headers = {"referer": "https://charts.youtube.com/charts/TopSongs/kr?hl=ko",
                  "accept-encoding": "gzip, deflate, br",
                  "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
                  "authorization": "SAPISIDHASH 1615096375_be1d47a52336b20b1443f457d537624ae293ccd7",
                  "content-type": "application/json",
                  "cookie": "VISITOR_INFO1_LIVE=5J8UKcxNGfI; PREF=tz=Asia.Seoul&f4=4000000&f5=30000;\
LOGIN_INFO=AFmmF2swRgIhAKWaN9Sj5iB5FYSqZnJglmX_8dxeLcBFcSH8h0Os-g1GAiEAhkHzsqGLbe0D8srt-IAhUnPzirQgOEC\
6Di9YoneTB9c:QUQ3MjNmeDZVMUlXYmJfeUNua2VMMFpWMGlRMFZuYlIzV3RiTk5TUWh4cjdGejRsa2xmNm5zV0RrV0h2bE5JWU5MUD\
JLdGpEY2hKalRMVEZYdTluZXVUNU5YTFFVWXRWV3BtV3ppTGN4TExNT05oajhiRFZqWXNzd1AzUktxd2xqVzkxVWUyT2tBVGZRRk9tZE\
VZaTR6RlNEbGdEcldkSU10di02cVV2TUw2ZEh6ejBFRi1hYktj; __Secure-3PSID=6gdq0K-2OKSbosz5aEmcDkaS9_uBOqA2raz4gO\
sg4H9cDW46jM1MtBo-vMu7rYqCcKObQQ.; __Secure-3PAPISID=Z2qX3xNav6N9NtbA/AuVVgR_Vr9syjHh95; _gcl_au=1.1.21298\
57006.1613996411; _ga=GA1.2.1850910574.1613996421; YSC=X-P5Wf3mZhk; _gid=GA1.2.753063154.1615041907; __Secu\
re-3PSIDCC=AJi4QfG0wb2623CCnCN4c9DSryxX1XkDWfiQjDTQsiBb4zZAveZV_foyTIiKUA3IXrTizOkfmuA; _gat=1",
                  "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/\
88.0.4324.190 Safari/537.36",
                  }
#         response = requests.post(url = self.start_urls, json=self.query, headers=headers)
        for url in self.start_urls:
            for body in self.query:
                yield scrapy.Request(url, method="POST", body=body,callback=self.list_parse,headers=headers)
          
    def list_parse(self, response):
        datas = response.json()["contents"]["sectionListRenderer"]["contents"][0]["musicAnalyticsSectionRenderer"]["content"]["trackTypes"][0]["trackViews"]
        for data in datas:
            yield scrapy.Request(data, callback=self.parse_content)
        
    def parse_content(self, response):
        item = YoutubeChartItem()
        item["name"] = {data["name"]}
        item["artist"] = {data["artists"][0]["name"]}
        item["viewCount"] = {data["viewCount"] + "M"}
        item["current_Rank"] = {data["chartEntryMetadata"].get('currentPosition')}
        item["previous_Rank"] = {data['chartEntryMetadata'].get('previousPosition')}
        item["change"] = {data['chartEntryMetadata'].get('percentViewsChange')}
        item["period_on_chart"] = {str(data['chartEntryMetadata'].get('periodsOnChart')) + " week"}
        itme["image"] = {data["thumbnail"]["thumbnails"][1]["url"]}
        item["play_url"] = {"https://www.youtube.com/watch?v=" + data["encryptedVideoId"]} 
        yield item
# Out:
# Overwriting youtube_chart/youtube_chart/spiders/spirder.py

# %%
# %%writefile run.sh
# cd ~/youtube_chart
# scrapy crawl YoutubeChart -o youtube_chart.csv
# Out:
# Overwriting run.sh

# %%
# !head -n 20 youtube_chart/youtube_chart/settings.py | tail -n 2
# Out:
# # Obey robots.txt rules
# ROBOTSTXT_OBEY = False

# %%
# !sed -i 's/ROBOTSTXT_OBEY = True/ROBOTSTXT_OBEY = False/' youtube_chart/youtube_chart/settings.py

# %%
# !/bin/bash run.sh
# Out:
# 2021-03-07 17:22:12 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: youtube_chart)
# 2021-03-07 17:22:12 [scrapy.utils.log] INFO: Versions: lxml 4.6.2.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.8.5 (default, Feb  5 2021, 06:49:19) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1j  16 Feb 2021), cryptography 3.4.6, Platform Linux-5.4.0-1037-aws-x86_64-with-glibc2.27
# 2021-03-07 17:22:12 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-03-07 17:22:12 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'youtube_chart',
#  'NEWSPIDER_MODULE': 'youtube_chart.spiders',
#  'SPIDER_MODULES': ['youtube_chart.spiders']}
# 2021-03-07 17:22:12 [scrapy.extensions.telnet] INFO: Telnet Password: 8c8aa4673299cb55
# 2021-03-07 17:22:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# !pwd
# Out:
# /home/ubuntu

# %%
! cat run.sh
# Out:
# cd ~/youtube_chart
# scrapy crawl YoutubeChart -o youtube_chart.csv

# %%
# !ls
# Out:
# 01_iterator_generator.ipynb		backup.sh
# 02_kakao_api_1.ipynb			chromedriver_linux64.zip
# 02_xpath.ipynb				dead.letter
# 03_kakao_api_2.ipynb			git_crawling_youtube.ipynb
# 03_scrapy_basic_gmarket.ipynb		just-camera-292600-a323bffa4574.json
# 04_google_api.ipynb			mbox
# 04_google_vision_api.ipynb		notebooks
# 05_xvfb.ipynb				park_class
# 06_scrapy_naver_news.ipynb		pyenv.sh
# 06_scrapy_selenium_naver_article.ipynb	python3
# 09_selenium_1.ipynb			requirements.txt
# 1.png					run.sh
# 10_selenium_2.ipynb			time.py
# 11_selenium_3.ipynb			time.txt
# 12_selenium_on_server.ipynb		tmp.sql
# 13_selenium_naver_article.ipynb		version.py
# 14_multinomialNB.ipynb			version.txt
# 20210216_1653.sql			weather.py
# Untitled.ipynb				youtube_chart
# backup					youtube_crawling.ipynb

# %%
# !scrapy crawl YoutubeChart
# Out:
# Scrapy 2.4.1 - no active project
#
# Unknown command: crawl
#
# Use "scrapy" to see available commands
